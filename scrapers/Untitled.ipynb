# %%
import pandas as pd

# %%
df =pd.read_csv('posts.csv')

# %%
df
# Out:
#     Unnamed: 0 Time                                        PostDetails  \
# 0            0   6d  Googler Joy Jackson shares what it’s like to w...
# 1            1  NaN                                                NaN
# 2            2   1w  Kent Walker, SVP of Global Affairs at Google, ...
# 3            3   3w  Wondering what it’s like to work at our Dublin...
# 4            4   2w  When you’re looking for a new role, why not tr...
# 5            5   1w  In the new series, Tech Bytes, #WomenTechmaker...
# 6            6   3w  “The beauty in us reclaiming Juneteenth is tha...
# 7            7   3w  A few years ago we started an inclusive market...
# 8            8   1w  “I was first introduced to computer science wh...
# 9            9   2w  “I jumped at the chance to put some of my idea...
# 10          10   2w  This year, we’re supporting LGBTQ+ communities...
# 11          11  1mo  ICYMI: Google CEO Sundar Pichai shared an upda...
# ...

# %%
dff = df[pd.notnull(df['PostDetails'])]
dff
# Out:
#     Unnamed: 0 Time                                        PostDetails  \
# 0            0   6d  Googler Joy Jackson shares what it’s like to w...
# 2            2   1w  Kent Walker, SVP of Global Affairs at Google, ...
# 3            3   3w  Wondering what it’s like to work at our Dublin...
# 4            4   2w  When you’re looking for a new role, why not tr...
# 5            5   1w  In the new series, Tech Bytes, #WomenTechmaker...
# 6            6   3w  “The beauty in us reclaiming Juneteenth is tha...
# 7            7   3w  A few years ago we started an inclusive market...
# 8            8   1w  “I was first introduced to computer science wh...
# 9            9   2w  “I jumped at the chance to put some of my idea...
# 10          10   2w  This year, we’re supporting LGBTQ+ communities...
# 11          11  1mo  ICYMI: Google CEO Sundar Pichai shared an upda...
# 12          12   2w  Google’s sustainability goals are ambitious—an...
#
#    likeCount  CommentCount
# ...
